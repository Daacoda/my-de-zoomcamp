# %%
# !uv add sqlalchemy "psycopg[binary,pool]"
# Out:
# Resolved 119 packages in 1ms
# Checked 24 packages in 0.26ms

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg://root:root@localhost:5432/ny_taxi')

# %%
import pandas as pd

print("Reading Green Taxi Parquet file...")
df_green = pd.read_parquet('green_tripdata_2025-11.parquet')
# Out:
# Reading Green Taxi Parquet file...

# %%
display(df_green.head(3))
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2025-11-01 00:34:48   2025-11-01 00:41:39                  N
# 1         2  2025-11-01 00:18:52   2025-11-01 00:24:27                  N
# 2         2  2025-11-01 01:03:14   2025-11-01 01:15:24                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0         1.0            74            42              1.0           0.74
# 1         1.0            74            42              2.0           0.95
# 2         1.0            83           160              1.0           2.19
#
#    fare_amount  ...  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# 0          7.2  ...      0.5        1.94           0.0        NaN
# 1          7.2  ...      0.5        0.00           0.0        NaN
# 2         13.5  ...      0.5        5.00           0.0        NaN
#
#    improvement_surcharge  total_amount  payment_type  trip_type  \
# ...

# %%
print("Pushing data to Postgres... (this might take a few seconds)")
df_green.to_sql(name='green_taxi_data', con=engine, if_exists='replace', index=False)
print("Green Taxi table successfully created and loaded!")
# Out:
# Pushing data to Postgres... (this might take a few seconds)
# Green Taxi table successfully created and loaded!

# %%
print("Reading Zone Lookup CSV file...")
df_zones = pd.read_csv('taxi_zone_lookup.csv')

print(f"Loaded {df_zones.shape[0]} zones. Previewing data:")
display(df_zones.head(3))

# Push to Postgres
df_zones.to_sql(name='zones', con=engine, if_exists='replace', index=False)
print("Zones table successfully created and loaded!")
# Out:
# Reading Zone Lookup CSV file...
# Loaded 265 zones. Previewing data:
#    LocationID Borough                     Zone service_zone
# 0           1     EWR           Newark Airport          EWR
# 1           2  Queens              Jamaica Bay    Boro Zone
# 2           3   Bronx  Allerton/Pelham Gardens    Boro Zone
# Zones table successfully created and loaded!

# %%
# Quick verify query
pd.read_sql("SELECT COUNT(*) FROM green_taxi_data;", con=engine)
# Out:
#    count
# 0  46912
